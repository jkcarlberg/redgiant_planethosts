# %%
# %matplotlib inline

import json
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
from scipy import interpolate
from operator import itemgetter
import matplotlib as mpl
from astropy.stats import sigma_clip

plt.style.use('seaborn-white')
mpl.rcParams.update({'font.size': 16})

# %% [markdown]
# # Finding the Optimal Lowercut Value (TAME parameter) per Line
# The lowercut value appears to be key to TAME assigning a good equivalent width measurement for a given line. This notebook uses measurements taken from ~20 stars at 10 different lowercut values to find the best lowercut value per line. Note that a lowercut value seems to be a SNR dependent parameter, so it might not be as simple as just finding a universal value per line.

# %%
# Take a look at one cluster
upper=False
#All Files
if upper:
    outputs = glob.glob("tame-1.1.0/*upper.json")
    by_hand = glob.glob("tame-1.1.0/*.ew")
    lc_range = np.arange(0.95,1.04,0.0001)
    len_range = 20

else:
    outputs = glob.glob("tame-1.1.0/*14.json")
    by_hand = glob.glob("tame-1.1.0/*.ew")
    lc_range = np.arange(0.95,0.995,0.0001)
    len_range = 10
#Fine Sampling
#outputs = glob.glob("tame-1.1.0/finesampling.json")
#by_hand = glob.glob("tame-1.1.0/col110_5125*.ew")


d = {'JSON File': outputs, 'By-Hand File': by_hand}
disp_df = pd.DataFrame(data=d)
disp_df
# Out:
#                                      By-Hand File  \
# 0       tame-1.1.0/col110_1134red_oned_25jan14.ew
# 1       tame-1.1.0/col110_2119red_oned_26jan14.ew
# 2       tame-1.1.0/col110_2129red_oned_25jan14.ew
# 3       tame-1.1.0/col110_2223red_oned_26jan14.ew
# 4       tame-1.1.0/col110_3122red_oned_mar2014.ew
# 5       tame-1.1.0/col110_3144red_oned_mar2014.ew
# 6       tame-1.1.0/col110_3244red_oned_25jan14.ew
# 7       tame-1.1.0/col110_4260red_oned_26jan14.ew
# 8       tame-1.1.0/col110_5125red_oned_26jan14.ew
# 9      tame-1.1.0/ngc2204_1124red_oned_05jan14.ew
# 10     tame-1.1.0/ngc2204_1212red_oned_06jan14.ew
# 11     tame-1.1.0/ngc2204_1330red_oned_06jan14.ew
# 12     tame-1.1.0/ngc2204_2212red_oned_05jan14.ew
# 13     tame-1.1.0/ngc2204_2229red_oned_06jan14.ew
# 14     tame-1.1.0/ngc2204_2311red_oned_06jan14.ew
# 15     tame-1.1.0/ngc2204_2330red_oned_06jan14.ew
# 16     tame-1.1.0/ngc2204_3205red_oned_06jan14.ew
# 17     tame-1.1.0/ngc2204_3215red_oned_05jan14.ew
# 18     tame-1.1.0/ngc2204_3321red_oned_05jan14.ew
# 19     tame-1.1.0/ngc2204_4115red_oned_06jan14.ew
# 20     tame-1.1.0/ngc2204_4116red_oned_05jan14.ew
# 21     tame-1.1.0/ngc2204_4119red_oned_06jan14.ew
# 22     tame-1.1.0/ngc2204_4211red_oned_05jan14.ew
# 23     tame-1.1.0/ngc2204_4223red_oned_05jan14.ew
# 24     tame-1.1.0/ngc2204_4303red_oned_05jan14.ew
# 25     tame-1.1.0/ngc2204_5352red_oned_05jan14.ew
# 26     tame-1.1.0/ngc2204_5980red_oned_05jan14.ew
# 27     tame-1.1.0/ngc2204_6330red_oned_05jan14.ew
# 28     tame-1.1.0/ngc2506_2380red_oned_26jan14.ew
# 29     tame-1.1.0/ngc2506_3265red_oned_26jan14.ew
# 30     tame-1.1.0/ngc2506_4138red_oned_26jan14.ew
# 31     tame-1.1.0/ngc2506_4205red_oned_25jan14.ew
# 32     tame-1.1.0/ngc2506_4240red_oned_25jan14.ew
# 33  tame-1.1.0/ngc6583_10red_oned_slit05_jun14.ew
# 34  tame-1.1.0/ngc6583_33red_oned_slit05_jun14.ew
# 35  tame-1.1.0/ngc6583_34red_oned_slit05_jun14.ew
# 36  tame-1.1.0/ngc6583_38red_oned_slit07_jun14.ew
# 37  tame-1.1.0/ngc6583_39red_oned_slit07_jun14.ew
# 38  tame-1.1.0/ngc6583_42red_oned_slit07_jun14.ew
# 39  tame-1.1.0/ngc6583_46red_oned_slit05_jun14.ew
# 40  tame-1.1.0/ngc6583_50red_oned_slit07_jun14.ew
# 41  tame-1.1.0/ngc6583_62red_oned_slit07_jun14.ew
# 42  tame-1.1.0/ngc6583_72red_oned_slit07_jun14.ew
# 43  tame-1.1.0/ngc6583_92red_oned_slit05_jun14.ew
#
#                                           JSON File
# 0       tame-1.1.0/col110_1134red_oned_25jan14.json
# 1       tame-1.1.0/col110_2119red_oned_26jan14.json
# 2       tame-1.1.0/col110_2129red_oned_25jan14.json
# 3       tame-1.1.0/col110_2223red_oned_26jan14.json
# 4       tame-1.1.0/col110_3122red_oned_mar2014.json
# 5       tame-1.1.0/col110_3144red_oned_mar2014.json
# 6       tame-1.1.0/col110_3244red_oned_25jan14.json
# 7       tame-1.1.0/col110_4260red_oned_26jan14.json
# 8       tame-1.1.0/col110_5125red_oned_26jan14.json
# 9      tame-1.1.0/ngc2204_1124red_oned_05jan14.json
# 10     tame-1.1.0/ngc2204_1212red_oned_06jan14.json
# 11     tame-1.1.0/ngc2204_1330red_oned_06jan14.json
# 12     tame-1.1.0/ngc2204_2212red_oned_05jan14.json
# 13     tame-1.1.0/ngc2204_2229red_oned_06jan14.json
# 14     tame-1.1.0/ngc2204_2311red_oned_06jan14.json
# 15     tame-1.1.0/ngc2204_2330red_oned_06jan14.json
# 16     tame-1.1.0/ngc2204_3205red_oned_06jan14.json
# 17     tame-1.1.0/ngc2204_3215red_oned_05jan14.json
# 18     tame-1.1.0/ngc2204_3321red_oned_05jan14.json
# 19     tame-1.1.0/ngc2204_4115red_oned_06jan14.json
# 20     tame-1.1.0/ngc2204_4116red_oned_05jan14.json
# 21     tame-1.1.0/ngc2204_4119red_oned_06jan14.json
# 22     tame-1.1.0/ngc2204_4211red_oned_05jan14.json
# 23     tame-1.1.0/ngc2204_4223red_oned_05jan14.json
# 24     tame-1.1.0/ngc2204_4303red_oned_05jan14.json
# 25     tame-1.1.0/ngc2204_5352red_oned_05jan14.json
# 26     tame-1.1.0/ngc2204_5980red_oned_05jan14.json
# 27     tame-1.1.0/ngc2204_6330red_oned_05jan14.json
# 28     tame-1.1.0/ngc2506_2380red_oned_26jan14.json
# 29     tame-1.1.0/ngc2506_3265red_oned_26jan14.json
# 30     tame-1.1.0/ngc2506_4138red_oned_26jan14.json
# 31     tame-1.1.0/ngc2506_4205red_oned_25jan14.json
# 32     tame-1.1.0/ngc2506_4240red_oned_25jan14.json
# 33  tame-1.1.0/ngc6583_10red_oned_slit05_jun14.json
# 34  tame-1.1.0/ngc6583_33red_oned_slit05_jun14.json
# 35  tame-1.1.0/ngc6583_34red_oned_slit05_jun14.json
# 36  tame-1.1.0/ngc6583_38red_oned_slit07_jun14.json
# 37  tame-1.1.0/ngc6583_39red_oned_slit07_jun14.json
# 38  tame-1.1.0/ngc6583_42red_oned_slit07_jun14.json
# 39  tame-1.1.0/ngc6583_46red_oned_slit05_jun14.json
# 40  tame-1.1.0/ngc6583_50red_oned_slit07_jun14.json
# 41  tame-1.1.0/ngc6583_62red_oned_slit07_jun14.json
# 42  tame-1.1.0/ngc6583_72red_oned_slit07_jun14.json
# 43  tame-1.1.0/ngc6583_92red_oned_slit05_jun14.json

# %%
for i in range(len(outputs)):
    with open(outputs[i]) as jsonfile, open(by_hand[i]) as ewfile:
        jsondata = json.load(jsonfile)
        handdata = pd.read_csv(ewfile, delim_whitespace = True, header = None)[[0,4]]
        hand_dict = dict(zip([str(i) for i in handdata[0].tolist()], handdata[4].tolist()))
        key = list(jsondata.keys())[3]
        lowercut = [cut for cut,ew in jsondata[key]]
        #print(outputs[i],len(lowercut),'6609.11' in jsondata.keys())

# %% [markdown]
# ### Finding Optimal Lowcut Value for each Line: Individual Solutions Method

# %%
# Find optimal lowercut value

plt.figure(figsize=(15,10),dpi=200)

text_out = False
for i in range(len(outputs)):
    with open(outputs[i]) as jsonfile, open(by_hand[i]) as ewfile:
        jsondata = json.load(jsonfile)
        handdata = pd.read_csv(ewfile, delim_whitespace = True, header = None)[[0,4]]
        hand_dict = dict(zip([str(i) for i in handdata[0].tolist()], handdata[4].tolist()))
        key = list(jsondata.keys())[2]
        #key = '5577.03'
        lowercut = [cut for cut,ew in jsondata[key]]
        ew_meas = [ew for cut,ew in jsondata[key]]
        
        label = disp_df['JSON File'][i].split('/')[-1].split('.')[0]
        if text_out:
            print("=========")
            print(label)
        if hand_dict[key] == 0:
            if text_out:
                print("SKIPPED STAR: By-Hand Value of 0")
            continue
        if len(lowercut) < len_range:
            if text_out:
                print("SKIPPED STAR: Not enough lowercut values")
            continue
        ew_pdiff = ((np.array(ew_meas)-hand_dict[key])/hand_dict[key]) * 100
        
        lowercut_space = lc_range
        f = interpolate.UnivariateSpline(lowercut, ew_pdiff, s=0)
        lowcut_roots = f.roots()
        if len(lowcut_roots) == 0:
            if min(abs(ew_pdiff)) > 10:
                if text_out:
                    print("WARNING: No good value found, using closest")
            opt_lowcut = [lowercut[np.argmin(abs(ew_pdiff))]]
        else:
            opt_lowcut = lowcut_roots


        #yToFind = 0
        #yreduced = np.array(ew_pdiff) - yToFind
        #freduced = interpolate.UnivariateSpline(lowercut, yreduced, s=0)
        #opt_lowcut = freduced.roots()

        if text_out:
            print("N Solutions: {}".format(len(lowcut_roots)))
            print("Optimal Lowercut Values: {}".format(opt_lowcut))
        #print(hand_dict[key],ew_meas[0])
        
        
        plt.plot(lowercut_space, f(lowercut_space),'-',label = label)
        plt.plot(lowercut,ew_pdiff,'.',color='k')


plt.title("Lowercut Value vs Percent Difference for Line at {}".format(key))
plt.xlabel("Lowercut Value")
plt.ylabel("Percent Difference (against by-hand values)")
plt.ylim(-40,40)
plt.grid()
#plt.legend()

# %%
# Find optimal lowercut value
mpl.rcParams.update({'font.size': 12})

with open(outputs[3]) as jsonfile:
    line_list = list(json.load(jsonfile).keys())
    line_list = np.array(sorted(np.array(line_list).astype(float))).astype(str)
fig = plt.figure(figsize=(10,80))
fig.dpi = 200
plots_per_row = 3

for idx,line in enumerate(line_list):
    ax = fig.add_subplot(int(len(line_list)/plots_per_row),plots_per_row,idx+1)
    #print(line)
    opt_lowcuts = []
    close_lowcuts = []
    n_solns = []
    
    for i in range(len(outputs)):
        if 'ngc2204_3321red' in outputs[i]:
            continue
        with open(outputs[i]) as jsonfile, open(by_hand[i]) as ewfile:
            jsondata = json.load(jsonfile)
            handdata = pd.read_csv(ewfile, delim_whitespace = True, header = None)[[0,4]]
            hand_dict = dict(zip([str(i) for i in handdata[0].tolist()], handdata[4].tolist()))
            key = line
            lowercut = [cut for cut,ew in jsondata[key]]
            ew_meas = [ew for cut,ew in jsondata[key]]
        
            label = disp_df['JSON File'][i].split('/')[-1].split('.')[0]

            if hand_dict[key] == 0:
                #print("SKIPPED STAR: By-Hand Value of 0")
                continue
            if len(lowercut) < len_range:
                #print("SKIPPED STAR: Not enough lowercut values")
                continue
            ew_pdiff = ((np.array(ew_meas)-hand_dict[key])/hand_dict[key]) * 100
        
            lowercut_space = lc_range
            f = interpolate.UnivariateSpline(lowercut, ew_pdiff, s=0)
            lowcut_roots = f.roots()
            if len(lowcut_roots) == 0:
                if min(abs(ew_pdiff)) > 10:
                    pass
                    #print("WARNING: No good value found, using closest")
                opt_lowcut = [lowercut[np.argmin(abs(ew_pdiff))]]
            else:
                opt_lowcut = lowcut_roots

        
            #print("N Solutions: {}".format(len(lowcut_roots)))
            #print("Optimal Lowercut Values: {}".format(opt_lowcut))
            if len(lowcut_roots) == 0:
                close_lowcuts.append(opt_lowcut)
            else:
                opt_lowcuts.append(opt_lowcut)
            n_solns.append(len(lowcut_roots))
    n_solns = np.array(n_solns)
    all_cutsolns = [soln[0] for soln in (solns for solns in opt_lowcuts)]
    all_cutclose = [soln[0] for soln in (solns for solns in close_lowcuts)]
    
    bins=np.histogram(np.hstack(all_cutsolns), bins=14)[1] #designate a consistent binsize across
    ax.hist(all_cutsolns,histtype='bar',ec='black',alpha=0.7,
            color='lightblue',bins=bins, label="Solutions")
    ax.hist(all_cutclose,histtype='bar',ec='black',alpha=0.7,
            color='firebrick',bins=bins, label="No Solutions")
    
    ax.set_xlabel("Solns: None:{}, 1:{}, 2:{}, >2:{}".format(sum(n_solns == 0),
                                                                      sum(n_solns == 1),
                                                                      sum(n_solns == 2),
                                                                      sum(n_solns > 2)))
    ax.set_title(line)
    ax.set_ylabel("Frequency")
    ax.set_xlim(0.95,1.04)
    plt.legend()


plt.tight_layout()
#plt.savefig("opt_lowcut_indiv_upper.png")
plt.close()

mpl.rcParams.update({'font.size': 16})

# %% [markdown]
# ### Finding Optimal Lowcut Value for each Line: Mean Solutions Method

# %%
# Find optimal lowercut value
key_element = 0

with open(outputs[0]) as jsonfile:
    jsondata = json.load(jsonfile)
    key = list(jsondata.keys())[key_element]
    lowcuts = [cut for cut,ew in jsondata[key]]

plt.figure(figsize=(15,10),dpi=200)

text_out = False
pdiff_all = []
for i in range(len(outputs)):
    with open(outputs[i]) as jsonfile, open(by_hand[i]) as ewfile:
        jsondata = json.load(jsonfile)
        handdata = pd.read_csv(ewfile, delim_whitespace = True, header = None)[[0,4]]
        hand_dict = dict(zip([str(i) for i in handdata[0].tolist()], handdata[4].tolist()))
        key = list(jsondata.keys())[key_element]
        #key = '5577.03'
        lowercut = [cut for cut,ew in jsondata[key]]
        ew_meas = [ew for cut,ew in jsondata[key]]
        
        label = disp_df['JSON File'][i].split('/')[-1].split('.')[0]
        if text_out:
            print("=========")
            print(label)
        if hand_dict[key] == 0:
            if text_out:
                print("SKIPPED STAR: By-Hand Value of 0")
            continue
        if len(lowercut) < len_range:
            if text_out:
                print("SKIPPED STAR: Not enough lowercut values")
            continue
        ew_pdiff = ((np.array(ew_meas)-hand_dict[key])/hand_dict[key]) * 100
        #print(lowercut)
        lowercut_space = lc_range
        f = interpolate.UnivariateSpline(lowercut, ew_pdiff, s=0)
        lowcut_roots = f.roots()
        if len(lowcut_roots) == 0:
            if min(abs(ew_pdiff)) > 10:
                if text_out:
                    print("WARNING: No good value found, using closest")
            opt_lowcut = [lowercut[np.argmin(ew_pdiff)]]
        else:
            opt_lowcut = lowcut_roots

        if text_out:
            print("N Solutions: {}".format(len(lowcut_roots)))
            print("Optimal Lowercut Values: {}".format(opt_lowcut))

        
        pdiff_all.append(ew_pdiff)

        #plt.plot(lowercut_space, f(lowercut_space),'-',label = label)
        plt.plot(lowercut,ew_pdiff,'.',color='k')


pdiff_all = np.array(pdiff_all,dtype='object').T

#Sigma Clip
sigma = 5
pdiff_sclip = [np.ma.compressed(sigma_clip(np.array(pdiff_all[lowcuts.index(lc_val)]).astype(float),sigma=sigma)) 
               for lc_val in lowcuts]


avg_pdiffs = [np.median(pdiff_sclip[lowcuts.index(lc_val)]) for lc_val in lowcuts]
std_pdiffs = [np.std(pdiff_sclip[lowcuts.index(lc_val)]) for lc_val in lowcuts]

f = interpolate.UnivariateSpline(lowcuts,np.array(avg_pdiffs)-0,s=0)
f_unc = interpolate.UnivariateSpline(lowcuts,std_pdiffs, s=0)


opt_lowcut = f.roots()

if len(lowcut_roots) == 0: 
    if write_out:
        print("No roots found, using closest data point\n")

    opt_lowcut = [lowercut[np.argmin(abs(np.array(avg_pdiffs)))]]
    if min(abs(np.array(avg_pdiffs))) > 10:
        if write_out:
            print("WARNING: No lowcut value yields a good agreement (<10%)\n")
else:
    opt_lowcut = lowcut_roots

print("Optimal Lowcut: ", opt_lowcut)
print("Standard Deviation of Percent Difference at Lowcut: ", f_unc(opt_lowcut))

lowcut_space = lc_range
plt.plot(lowcut_space, f(lowcut_space),'-')
#plt.plot(lowercut,avg_pdiffs,'.')
#plt.plot([0.95]*len(pdiff_sclip[lowcuts.index(0.95)]),pdiff_sclip[lowcuts.index(0.95)],'.')
plt.title("Lowercut Value vs Percent Difference for Line at {}".format(key))
plt.xlabel("Lowercut Value")
plt.ylabel("Percent Difference (against by-hand values)")
#plt.ylim(-40,40)
plt.grid()
#plt.legend()
# Out:
# Optimal Lowcut:  [ 0.98328073]
# Standard Deviation of Percent Difference at Lowcut:  [ 8.50902719]

# %%
# Find optimal lowercut value
write_out = True

with open(outputs[0]) as jsonfile:
    jsondata = json.load(jsonfile)
    key = list(jsondata.keys())[2]
    lowcuts = [cut for cut,ew in jsondata[key]]
    line_list = list(jsondata.keys())
    line_list = np.array(sorted(np.array(line_list).astype(float))).astype(str)

if write_out:
    f_out = open("mean_lc_byline_upper.txt","w")
solns_dev = []
closest_dev = []
closest_pdiffs = []

for line in line_list:
    f_out.write("=======\n")
    f_out.write("Line: {}\n".format(line))
    pdiff_all = []
    for i in range(len(outputs)):
        if 'ngc2204_3321red' in outputs[i]:
            continue
        with open(outputs[i]) as jsonfile, open(by_hand[i]) as ewfile:
            jsondata = json.load(jsonfile)
            handdata = pd.read_csv(ewfile, delim_whitespace = True, header = None)[[0,4]]
            hand_dict = dict(zip([str(i) for i in handdata[0].tolist()], handdata[4].tolist()))
            key = line
            lowercut = [cut for cut,ew in jsondata[key]]
            ew_meas = [ew for cut,ew in jsondata[key]]
            
            label = disp_df['JSON File'][i].split('/')[-1].split('.')[0]
            if hand_dict[key] == 0:
                continue
            if len(lowercut) < len_range:
                continue
            ew_pdiff = ((np.array(ew_meas)-hand_dict[key])/hand_dict[key]) * 100
            #print(lowercut)
            lowercut_space = lc_range
            f = interpolate.UnivariateSpline(lowercut, ew_pdiff, s=0)
            lowcut_roots = f.roots()
            if len(lowcut_roots) == 0:
                opt_lowcut = [lowercut[np.argmin(ew_pdiff)]]
            else:
                opt_lowcut = lowcut_roots
    
            
            pdiff_all.append(ew_pdiff)
    

    pdiff_all = np.array(pdiff_all,dtype='object').T

    #Sigma Clip
    sigma = 5
    pdiff_sclip = [np.ma.compressed(sigma_clip(np.array(pdiff_all[lowcuts.index(lc_val)]).astype(float),sigma=sigma)) 
                   for lc_val in lowcuts]


    avg_pdiffs = [np.median(pdiff_sclip[lowcuts.index(lc_val)]) for lc_val in lowcuts]
    std_pdiffs = [np.std(pdiff_sclip[lowcuts.index(lc_val)]) for lc_val in lowcuts]

    f = interpolate.UnivariateSpline(lowcuts,np.array(avg_pdiffs)-0,s=0)
    f_unc = interpolate.UnivariateSpline(lowcuts,std_pdiffs, s=0)


    opt_lowcut = f.roots()
    
    if len(lowcut_roots) == 0: 
        if write_out:
            f_out.write("No roots found, using closest data point\n")

        opt_lowcut = [lowercut[np.argmin(abs(np.array(avg_pdiffs)))]]
        if min(abs(np.array(avg_pdiffs))) > 10:
            if write_out:
                f_out.write("WARNING: No lowcut value yields a good agreement (<10%)\n")
    else:
        opt_lowcut = lowcut_roots

    
    if write_out:
        f_out.write("Optimal Lowcut: {}\n".format(opt_lowcut))
        f_out.write("Standard Deviation of Percent Difference at Lowcut: {}\n".format(f_unc(opt_lowcut)))

    best_lowcut = opt_lowcut[np.argmin(f_unc(opt_lowcut))] #Best lowcut is solution with smallest spread
    best_dev = f_unc(opt_lowcut)[np.argmin(f_unc(opt_lowcut))]
    
    if len(lowcut_roots) == 0: # No True Solutions
        closest_dev.append(best_dev)
        closest_pdiffs.append(f(best_lowcut))
    else:
        solns_dev.append(best_dev)
        
    

    line_dev.append(best_dev)
if write_out:
    f_out.close()

# %%
#Sigma Clip
sigma = 5

solns_sclip = np.ma.compressed(sigma_clip(solns_dev,sigma=sigma))
closest_sclip = np.ma.compressed(sigma_clip(closest_dev,sigma=sigma))




bins=np.histogram(np.hstack(line_sclip), bins=30)[1] #designate a consistent binsize across 
plt.figure(figsize=(15,10),dpi=200)
plt.hist(solns_sclip,histtype='bar',ec='black',alpha=0.8,color='lightblue',bins=bins,label='Solutions Exist')
plt.hist(closest_sclip,histtype='bar',ec='black',alpha=0.6,color='firebrick',bins=bins,label='Closest Point Used')
plt.ylabel("Frequency")
plt.xlabel("Uncertainty of Percent Difference")
plt.title("Uncertainty in Percent Difference for each Optimal Lowcut")
plt.grid()
plt.legend()

#print("Median and Standard Deviation for Lines with Solutions (N = {}): ".format(len(solns_sclip)),
#      np.median(solns_sclip),np.std(solns_sclip))
#print("Median and Standard Deviation for Lines without Solutions (N = {}): ".format(len(closest_sclip)),
#      np.median(closest_sclip),np.std(closest_sclip))
print("Solution Percentiles: 50%:{}, 75%:{}, 90%:{}, 95%:{}".format(np.percentile(solns_sclip,50),
                                                           np.percentile(solns_sclip,75),
                                                           np.percentile(solns_sclip,90),
                                                           np.percentile(solns_sclip,95)))
print("Closest Value Percentiles: 50%:{}, 75%:{}, 90%:{}, 95%:{}".format(np.percentile(closest_sclip,50),
                                                           np.percentile(closest_sclip,75),
                                                           np.percentile(closest_sclip,90),
                                                           np.percentile(closest_sclip,95)))
#plt.savefig("uncertainty_by_lowcut.png")
# Out:
# Solution Percentiles: 50%:6.007834839172698, 75%:10.516327369147442, 90%:19.11650669659042, 95%:30.01019850310024
# Closest Value Percentiles: 50%:7.222829579882297, 75%:30.753146999912836, 90%:55.03640837092817, 95%:76.30090035039606

# %%
#Sigma Clip
sigma = 5

solns_sclip = np.ma.compressed(sigma_clip(solns_dev,sigma=sigma))
closest_sclip = np.ma.compressed(sigma_clip(closest_dev,sigma=sigma))


solns_values, solns_base = np.histogram(solns_sclip, bins=40)
closest_values, closest_base = np.histogram(closest_sclip, bins=40)
#evaluate the cumulative
solns_cumulative = np.cumsum(solns_values)
closest_cumulative = np.cumsum(closest_values)

plt.figure(figsize=(15,10),dpi=200)
# plot the cumulative function
plt.plot(solns_base[:-1], solns_cumulative/len(solns_sclip)*100, c='lightblue',label = "Solutions Exist")
plt.plot(closest_base[:-1], closest_cumulative/len(closest_sclip)*100, c='firebrick',label = "Closest Point Used")
#plot the survival function
#plt.plot(base[:-1], len(solns_sclip)-cumulative, c='green')
plt.title("Cumulative Distribution Function")
plt.grid()
plt.legend()
plt.ylabel("Percentile")
plt.xlabel("Percent Difference Uncertainty in Lowcut Solution")

# %%
#Sigma Clip
sigma = 5

pdiff_sclip = np.ma.compressed(sigma_clip(closest_pdiffs,sigma=sigma))




bins=np.histogram(np.hstack(pdiff_sclip), bins=20)[1] #designate a consistent binsize across 
plt.figure(figsize=(15,10),dpi=200)
plt.hist(pdiff_sclip,histtype='bar',ec='black',alpha=0.7,color='firebrick',bins=bins,label='Closest Points Used')
plt.ylabel("Frequency")
plt.xlabel("Percent Difference")
plt.title("Distribution of Closest Percent Differences for Lines with no Solutions")
plt.grid()
plt.legend()

print("Median and Standard Deviation for Lines without Solutions (N = {}): ".format(len(pdiff_sclip)),
      np.median(pdiff_sclip),np.std(pdiff_sclip))
# Out:
# Median and Standard Deviation for Lines without Solutions (N = 16):  0.0397772474145 1.60062074502

# %%
print(closest_base)
# Out:
# [  4.35308789   5.80418675   7.25528562   8.70638448  10.15748334
#   11.60858221  13.05968107  14.51077994  15.9618788   17.41297767
#   18.86407653  20.31517539  21.76627426  23.21737312  24.66847199
#   26.11957085  27.57066972  29.02176858  30.47286744  31.92396631
#   33.37506517  34.82616404  36.2772629   37.72836177  39.17946063
#   40.63055949  42.08165836  43.53275722  44.98385609  46.43495495
#   47.88605382  49.33715268  50.78825154  52.23935041  53.69044927
#   55.14154814  56.592647    58.04374586  59.49484473  60.94594359
#   62.39704246]

# %%
sorted(solns_sclip)
# Out:
# [0.72174656510419677,
#  1.4222659553874202,
#  1.4272485757662401,
#  1.8945592478173912,
#  2.1653184718194902,
#  2.1717337810244377,
#  2.2722842159832903,
#  2.3774202192591742,
#  2.5961537299959225,
#  2.6197848584709429,
#  2.714678213391875,
#  2.8047377040929766,
#  3.2057597412818111,
#  3.2968886843020377,
#  3.4970114997978166,
#  3.7336637117541871,
#  3.9125907928591537,
#  3.992508712071797,
#  4.1551166475439905,
#  4.4506845839637057,
#  4.5072400192368907,
#  4.5207420140213328,
#  4.7997747119802332,
#  4.9507610623615061,
#  5.1499991232254381,
#  5.2916967509123376,
#  5.3667849640072571,
#  5.6299048560728941,
#  5.7351285961263869,
#  5.918123360858794,
#  6.0366524868764087,
#  6.1103550902576256,
#  6.1415807435483005,
#  6.1991130991687706,
#  6.6063896611989321,
#  6.7796811561743144,
#  7.035446651954568,
#  7.2300796614701435,
#  7.5362808594909705,
#  7.5770412369884346,
#  7.6439503523713723,
#  7.7640843964899142,
#  7.8395822700544313,
#  7.9539700594726099,
#  9.118107721412521,
#  10.11901879057687,
#  10.564360421832216,
#  10.615133281753968,
#  11.054084736402171,
#  12.011461616671735,
#  12.733489966471227,
#  14.080406046468841,
#  15.75472376318732,
#  15.847334161255279,
#  16.414209018612656,
#  21.239271523064662,
#  21.382757169597213,
#  21.672032410537032,
#  25.618065389483778,
#  27.947571191119525,
#  37.661267813735371,
#  40.193539984732979,
#  45.575621773416763,
#  58.994765550239137,
#  62.852792982422002,
#  76.647434340948564,
#  81.712402199465529]
